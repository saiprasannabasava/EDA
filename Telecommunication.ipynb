# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Cleaned Dataset
path="C:\\Users\\basva\\Downloads\\churn_dataset.csv"
df=pd.read_csv(path)     # importing Data
df.head(6)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# ...

# %%
# Type of Dataset
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#shape of Dataset
df.shape
# Out:
# (7043, 21)

# %%
# columns in Dataset
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# Information about Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df["TotalCharges"] = df["TotalCharges"].replace(" ",np.nan)

# %%
df['TotalCharges'] = df['TotalCharges'].astype(float) # changing object data type into float data type

# %%
# Information about Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df = df.dropna(subset=['TotalCharges']) # Droping null values from TotalCharges

# %%
#checking null values in Dataset
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
#  # Non-visualization analysis(Numerical columns)

# %%
print(df['SeniorCitizen'].min())  # minimum value of SeniorCitizen
print(df['SeniorCitizen'].max())  # maximum value of SeniorCitizen
print(df['SeniorCitizen'].mean()) # mean of SeniorCitizen
print(df['SeniorCitizen'].median()) # median of SeniorCitizen 
print(df['SeniorCitizen'].std())  #std of SeniorCitizen
# Out:
# 0
# 1
# 0.16240045506257111
# 0.0
# 0.3688439967571208

# %%
print(df['tenure'].min())  # minimum value of tenure
print(df['tenure'].max())  # maximum value of tenure
print(df['tenure'].mean()) # mean of tenure
print(df['tenure'].median()) # median of tenure 
print(df['tenure'].std())  #std of tenure
# Out:
# 1
# 72
# 32.421786120591584
# 29.0
# 24.545259709263192

# %%
print(df['MonthlyCharges'].min())  # minimum value of MonthlyCharges
print(df['MonthlyCharges'].max())  # maximum value of MonthlyCharges
print(df['MonthlyCharges'].mean()) # mean of MonthlyCharges
print(df['MonthlyCharges'].median()) # median of MonthlyCharges 
print(df['MonthlyCharges'].std())  #std of MonthlyCharges
# Out:
# 18.25
# 118.75
# 64.79820819112632
# 70.35
# 30.08597388404983

# %%
print(df['TotalCharges'].min())  # minimum value of TotalCharges
print(df['TotalCharges'].max())  # maximum value of TotalCharges
print(df['TotalCharges'].mean()) # mean of TotalCharges
print(df['TotalCharges'].median()) # median of TotalCharges
print(df['TotalCharges'].std())  #std of TotalCharges
# Out:
# 18.8
# 8684.8
# 2283.3004408418697
# 1397.475
# 2266.7713618831453

# %% [markdown]
# # Non-visualization analysis(Categorical columns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %%
df['customerID'].value_counts(normalize=True)
# Out:
# 7590-VHVEG    0.000142
# 0265-PSUAE    0.000142
# 2956-GGUCQ    0.000142
# 6008-NAIXK    0.000142
# 5956-YHHRX    0.000142
#                 ...
# 7874-ECPQJ    0.000142
# 9796-MVYXX    0.000142
# 2637-FKFSY    0.000142
# 1552-AAGRX    0.000142
# 3186-AJIEK    0.000142
# Name: customerID, Length: 7032, dtype: float64

# %%
df['gender'].value_counts(normalize=True)
# Out:
# Male      0.504693
# Female    0.495307
# Name: gender, dtype: float64

# %%
df['Partner'].value_counts(normalize=True)
# Out:
# No     0.517491
# Yes    0.482509
# Name: Partner, dtype: float64

# %%
df['Dependents'].value_counts(normalize=True)
# Out:
# No     0.701507
# Yes    0.298493
# Name: Dependents, dtype: float64

# %%
df['PhoneService'].value_counts(normalize=True)
# Out:
# Yes    0.903299
# No     0.096701
# Name: PhoneService, dtype: float64

# %%
df['MultipleLines'].value_counts(normalize=True)
# Out:
# No                  0.481371
# Yes                 0.421928
# No phone service    0.096701
# Name: MultipleLines, dtype: float64

# %%
df['InternetService'].value_counts(normalize=True)
# Out:
# Fiber optic    0.440273
# DSL            0.343572
# No             0.216155
# Name: InternetService, dtype: float64

# %%
df['OnlineSecurity'].value_counts(normalize=True)
# Out:
# No                     0.497298
# Yes                    0.286547
# No internet service    0.216155
# Name: OnlineSecurity, dtype: float64

# %%
df['OnlineBackup'].value_counts(normalize=True)
# Out:
# No                     0.438993
# Yes                    0.344852
# No internet service    0.216155
# Name: OnlineBackup, dtype: float64

# %%
df['DeviceProtection'].value_counts(normalize=True)
# Out:
# No                     0.439989
# Yes                    0.343857
# No internet service    0.216155
# Name: DeviceProtection, dtype: float64

# %%
df['TechSupport'].value_counts(normalize=True)
# Out:
# No                     0.493743
# Yes                    0.290102
# No internet service    0.216155
# Name: TechSupport, dtype: float64

# %%
df['StreamingTV'].value_counts(normalize=True)
# Out:
# No                     0.399460
# Yes                    0.384386
# No internet service    0.216155
# Name: StreamingTV, dtype: float64

# %%
df['StreamingMovies'].value_counts(normalize=True)
# Out:
# No                     0.395478
# Yes                    0.388367
# No internet service    0.216155
# Name: StreamingMovies, dtype: float64

# %%
df['Contract'].value_counts(normalize=True)
# Out:
# Month-to-month    0.551052
# Two year          0.239619
# One year          0.209329
# Name: Contract, dtype: float64

# %%
df['PaperlessBilling'].value_counts(normalize=True)
# Out:
# Yes    0.592719
# No     0.407281
# Name: PaperlessBilling, dtype: float64

# %%
df['PaymentMethod'].value_counts(normalize=True)
# Out:
# Electronic check             0.336320
# Mailed check                 0.228100
# Bank transfer (automatic)    0.219283
# Credit card (automatic)      0.216297
# Name: PaymentMethod, dtype: float64

# %%
df['Churn'].value_counts(normalize=True)
# Out:
# No     0.734215
# Yes    0.265785
# Name: Churn, dtype: float64

# %% [markdown]
# # Univariate analysis(numerical columns)

# %%
def plot_box(df):
    for column in df.columns:
        if df[column].dtype == np.int64 or df[column].dtype == np.float64:
            if column == 'SeniorCitizen':
                df['SeniorCitizen'].value_counts(normalize=True).plot(kind='box')
                plt.title('SeniorCitizen')
                plt.show()
            else:
                plot_box = df.boxplot( column=column)
                plt.title(f"{column}")
                plt.show()
plot_box(df)

# %% [markdown]
# * Box plot is used for univariate and bivariate analysis.
# * Box plot is used to find the outliers.
# * Here we draw box plot for numerical columns and we didn't find any outliers in it.

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Univariate analysis(Categorical column)

# %%
def plot_bar(df):
    for column in df.columns:
        if df[column].dtype == np.object:
            if column == 'customerID':
                print('No need to plot for "customerID" column.')
            else:
                counts = df[column].value_counts()
                counts.plot(kind='bar')
                plt.title(column)
                plt.show()
plot_bar(df)
# Out:
# No need to plot for "customerID" column.

# %% [markdown]
# * From above countplot dependents customers are less compared to
#   non dependents.
# * From above countplot phoneservice are high.
# * From above countplot most of the customers has no multiplelines
#   connection.
# * From above countplot more customers uses fiber optic
#   internetService compared to others.
# * Most customres has no onlineSecurity.
# * most of the customers has no OnlineBackup
# * Most of the customers has no deviceprotection

# %% [markdown]
# # Bivariate analysis(cat vs num)

# %%
def plot_box(df):
    a = df["Churn"]
    for column in df.columns:
        if df[column].dtype == np.int64 or df[column].dtype == np.float64 :
            plot_box = df.boxplot( by="Churn",column=column)
            plt.title(f"Churn vs {column}")
            plt.show()
plot_box(df)

# %% [markdown]
# # Bivariate analysis(cat vs cat)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %%
def plot_stack(df):
    a = df["Churn"]
    for column in df.columns:
        if df[column].dtype == np.object:
            if column=='customerID':
                print('No need to plot for "customerID" column.')
            else:    
                plot_stck = pd.crosstab(index=df[column], columns=a)
                plot_stck.plot(kind='bar', stacked=True)
                plt.title(f" Churn vs {column}")
                
                plt.show()
plot_stack(df)
# Out:
# No need to plot for "customerID" column.

# %% [markdown]
# # Conclusions:
#  * Customers subscribed to specific services, such as online security,
#    online backup, device protection, and tech support, may be more likely
#    to churn.
# *  The telecom company should investigate the quality, availability, and
#    value proposition of these services to improve customer retention.
# * The contract type, payment method, and paperless billing options may
#   influence customer churn.
# * Consider offering flexible contract options, convenient payment
#   methods, and incentives for paperless billing to encourage customer
#   loyalty.
# * High monthly charges and total charges may contribute to customer
#   churn. Evaluate pricing strategies and ensure that customers perceive
#   the value of the services they receive.
# * Demographic factors may play a role in churn.
# * Tailor marketing campaigns and customer retention strategies based on
#   gender, age range, and family status

# %% [markdown]
# # Recommendations
#  Conduct customer surveys or interviews to gain qualitative insights
# into the reasons behind churn and gather feedback on service quality
# and customer experience.
# * Implement proactive customer retention measures, such as
#   personalized offers, loyalty programs, or customer service
#   enhancements, for customers identified as high-risk for churn.
# * Regularly review and update service offerings to align with customer
#   needs and preferences, considering market trends and competitors.
# * Invest in improving customer support channels, ensuring prompt and
#   effective resolutions to customer issues and concerns.
# * Develop data-driven churn prediction models to identify at-risk
#   customers and implement targeted interventions to reduce churn.

# %%
df.to_csv('Telecommunication')
